# %%
# Intialization
import os
import sys

os.environ["SPARK_HOME"] = "/home/talentum/spark"
os.environ["PYLIB"] = os.environ["SPARK_HOME"] + "/python/lib"
# In below two lines, use /usr/bin/python2.7 if you want to use Python 2
os.environ["PYSPARK_PYTHON"] = "/usr/bin/python3.6" 
os.environ["PYSPARK_DRIVER_PYTHON"] = "/usr/bin/python3"
sys.path.insert(0, os.environ["PYLIB"] +"/py4j-0.10.7-src.zip")
sys.path.insert(0, os.environ["PYLIB"] +"/pyspark.zip")

# NOTE: Whichever package you want mention here.
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.11:0.6.0 pyspark-shell' 
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-avro_2.11:2.4.0 pyspark-shell'
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.11:0.6.0,org.apache.spark:spark-avro_2.11:2.4.3 pyspark-shell'
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.11:0.6.0,org.apache.spark:spark-avro_2.11:2.4.0 pyspark-shell'

# %%
#Entrypoint 2.x
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Spark SQL basic example").getOrCreate()

# On yarn:
# spark = SparkSession.builder.appName("Spark SQL basic example").enableHiveSupport().master("yarn").getOrCreate()
# specify .master("yarn")

sc = spark.sparkContext

# %%
# Read CSV file
df = spark.read.csv("NYC_Parking_Ticket_Analysis.csv", header=True, inferSchema=True, sep=',', quote='"', escape='"')

# Limit to first 10,000 rows
# sample_df = df.limit(10000)

# Show the limited DataFrame
# sample_df.show()

# %%
from pyspark.sql.functions import col

# Calculate the number of non-null values for each column
non_null_counts = {col_name: df.filter(col(col_name).isNotNull()).count() for col_name in df.columns}

# Print the number of non-null values for each column
# print("Non-null values for each column:")
# for col_name, non_null_count in non_null_counts.items():
#    print(f"{col_name}: {non_null_count}")

# Collect the result as a dictionary
# print("Non-null values as dictionary:")
# print(non_null_counts)

# Calculate the threshold for 80% non-null values
total_rows = df.count()
threshold = 0.8 * total_rows

# Select columns that meet the threshold
selected_columns = [col_name for col_name, non_null_count in non_null_counts.items() if non_null_count >= threshold]

# Create a new DataFrame with only the selected columns
df_selected = df.select(selected_columns)

# Print the selected columns
##print("Columns with at least 80% non-null values:")
# print(selected_columns)

# Show the resulting DataFrame
# df_selected.show()

# %%
len(df_selected.columns)
# Out:
# 31

# %%
# Check for missing values
missing_values = {col_name: df_selected.filter(col(col_name).isNull()).count() for col_name in df_selected.columns}
print("Missing values for each column:")
for col_name, missing_count in missing_values.items():
    print(f"{col_name}: {missing_count}")
# Out:
# Missing values for each column:
# Summons Number: 0
# Plate ID: 5
# Registration State: 0
# Plate Type: 0
# Issue Date: 0
# Violation Code: 0
# Vehicle Body Type: 195873
# Vehicle Make: 202263
# Issuing Agency: 0
# Street Code1: 0
# Street Code2: 0
# Street Code3: 0
# Vehicle Expiration Date: 1
# Violation Location: 4338996
# Violation Precinct: 2
# Issuer Precinct: 1
# Issuer Code: 2
# Issuer Command: 4296253
# Issuer Squad: 4296929
# Violation Time: 8069
# Violation County: 4259979
# Violation In Front Of Or Opposite: 4593303
# House Number: 4880498
# Street Name: 19234
# Date First Observed: 12
# Law Section: 5
# Sub Division: 4485
# Vehicle Color: 335501
# Vehicle Year: 36
# Feet From Curb: 43
# Violation Description: 3751349

# %%
# List of columns to keep
selected_columns = [
    'Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
    'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
    'Issuing Agency',
    'Violation Precinct', 'Violation Time', 'Violation County', 'Street Name',
    'Law Section', 'Sub Division', 'Vehicle Color', 'Feet From Curb', 'Violation Description'
]

# Create a new DataFrame with only the selected columns
df_clean_1 = df_selected.select(*selected_columns)

# Show the result
# df_clean_1.show()

# %%
df_no_duplicates = df_clean_1.dropDuplicates()
df_no_duplicates.count()
# Out:
# 30459729

# %%
df_cleaned = df_no_duplicates.dropna()
df_cleaned.count()
# Out:
# 23008035

# %%
# Check for missing values
missing_values = {col_name: df_cleaned.filter(col(col_name).isNull()).count() for col_name in df_cleaned.columns}
print("Missing values for each column:")
for col_name, missing_count in missing_values.items():
    print(f"{col_name}: {missing_count}")
# Out:
# Missing values for each column:
# Summons Number: 0
# Plate ID: 0
# Registration State: 0
# Plate Type: 0
# Issue Date: 0
# Violation Code: 0
# Vehicle Body Type: 0
# Vehicle Make: 0
# Issuing Agency: 0
# Violation Precinct: 0
# Violation Time: 0
# Violation County: 0
# Street Name: 0
# Law Section: 0
# Sub Division: 0
# Vehicle Color: 0
# Feet From Curb: 0
# Violation Description: 0

# %%
df_cleaned.select("Violation Time").show(10)
# Out:
# +--------------+
# |Violation Time|
# +--------------+
# |         0001A|
# |         0003A|
# |         0020A|
# |         0023A|
# |         0027A|
# |         0030A|
# |         0042A|
# |         0056A|
# |         0100A|
# |         0100A|
# +--------------+
# only showing top 10 rows

# %%
# Description of Summons Number Column
#df_cleaned.describe("Summons Number").show()

# Description of Plate ID Column
#df_cleaned.describe("Plate ID").show()

# Description of Registration State Column
#df_cleaned.describe("Registration State").show()

# Description of Violation Code Column
#df_cleaned.describe("Violation Code").show()

# %%
# df_cleaned.show(1,vertical=True)

# %%
df_cleaned.select("Violation Time").dtypes
# Out:
# [('Violation Time', 'string')]

# %%
from pyspark.sql.functions import col, to_date, to_timestamp, lpad, concat_ws
from pyspark.sql.types import IntegerType

# %%
from pyspark.sql.functions import col, lpad, substring, concat_ws, when

# Convert 'Violation Time' from 'HHMMX' to 'HH:MM AM/PM'
df_cleaned = df_cleaned.withColumn(
    "Violation Time",
    concat_ws(' ',
        concat_ws(':',
            lpad(substring(col("Violation Time"), 1, 2), 2, '0'),  # Hour part
            lpad(substring(col("Violation Time"), 3, 2), 2, '0')   # Minute part
        ),
        when(substring(col("Violation Time"), 5, 1) == 'A', 'AM')  # AM/PM part
        .otherwise('PM')
    )
)

# Show the resulting DataFrame
df_cleaned.select("Violation Time").show(30, truncate=False)
# Out:
# +--------------+
# |Violation Time|
# +--------------+
# |00:01 AM      |
# |00:03 AM      |
# |00:20 AM      |
# |00:23 AM      |
# |00:27 AM      |
# |00:30 AM      |
# |00:42 AM      |
# |00:56 AM      |
# |01:00 AM      |
# |01:00 AM      |
# |01:00 PM      |
# |01:00 PM      |
# |01:00 PM      |
# |01:00 PM      |
# |01:01 PM      |
# |01:01 PM      |
# |01:01 PM      |
# |01:02 PM      |
# |01:02 PM      |
# |01:02 PM      |
# |01:02 PM      |
# |01:03 PM      |
# |01:04 PM      |
# |01:04 PM      |
# |01:05 AM      |
# |01:05 PM      |
# |01:05 PM      |
# |01:06 PM      |
# |01:06 PM      |
# |01:06 PM      |
# +--------------+
# only showing top 30 rows

# %%
df_cleaned.select("Violation Time").dtypes
# Out:
# [('Violation Time', 'string')]

# %%
from pyspark.sql.functions import to_timestamp, col

# Convert 'Violation Time' from 'HH:MM AM/PM' string to timestamp
df_cleaned = df_cleaned.withColumn(
    "Violation Time",
    to_timestamp(col("Violation Time"), "hh:mm a")
)

# Show the resulting DataFrame
df_cleaned.select("Violation Time").show(20, truncate=False)
# Out:
# +-------------------+
# |Violation Time     |
# +-------------------+
# |null               |
# |null               |
# |null               |
# |null               |
# |null               |
# |null               |
# |null               |
# |null               |
# |1970-01-01 01:00:00|
# |1970-01-01 01:00:00|
# |1970-01-01 13:00:00|
# |1970-01-01 13:00:00|
# |1970-01-01 13:00:00|
# |1970-01-01 13:00:00|
# |1970-01-01 13:01:00|
# |1970-01-01 13:01:00|
# |1970-01-01 13:01:00|
# |1970-01-01 13:02:00|
# |1970-01-01 13:02:00|
# |1970-01-01 13:02:00|
# +-------------------+
# only showing top 20 rows

# %%
df_cleaned = df_cleaned.withColumn("Issue Date", to_date(col("Issue Date"), "MM/dd/yyyy"))

# %%
df_cleaned.dtypes
# Out:
# [('Summons Number', 'bigint'),
#  ('Plate ID', 'string'),
#  ('Registration State', 'string'),
#  ('Plate Type', 'string'),
#  ('Issue Date', 'date'),
#  ('Violation Code', 'int'),
#  ('Vehicle Body Type', 'string'),
#  ('Vehicle Make', 'string'),
#  ('Issuing Agency', 'string'),
#  ('Violation Precinct', 'int'),
#  ('Violation Time', 'timestamp'),
#  ('Violation County', 'string'),
#  ('Street Name', 'string'),
#  ('Law Section', 'string'),
#  ('Sub Division', 'string'),
#  ('Vehicle Color', 'string'),
#  ('Feet From Curb', 'string'),
#  ('Violation Description', 'string')]

# %%
df_cleaned.select("Issue Date").show(10)
# Out:
# +----------+
# |Issue Date|
# +----------+
# |2013-08-23|
# |2013-08-09|
# |2013-08-23|
# |2013-08-17|
# |2013-08-02|
# |2013-08-21|
# |2013-08-24|
# |2013-07-30|
# |2013-08-08|
# |2013-08-22|
# +----------+
# only showing top 10 rows

# %%
df_cleaned.coalesce(1).write.format("csv") \
  .option("header", "true") \
  .mode("overwrite") \
  .save("output_final_NYC.csv")

# %%
num_rows = df_cleaned.count()
num_columns = len(df_cleaned.columns)
print(f"Shape of DataFrame: ({num_rows}, {num_columns})")
# Out:
# Shape of DataFrame: (23008035, 18)

# %%
df_cleaned.show(10,vertical=True)
# Out:
# -RECORD 0-------------------------------------
#  Summons Number        | 7440710630
#  Plate ID              | 84790MA
#  Registration State    | NY
#  Plate Type            | COM
#  Issue Date            | 2013-08-23
#  Violation Code        | 78
#  Vehicle Body Type     | PICK
#  Vehicle Make          | FORD
#  Issuing Agency        | T
#  Violation Precinct    | 114
#  Violation Time        | null
#  Violation County      | Q
#  Street Name           | 37th St
#  Law Section           | 408
#  Sub Division          | k6
#  Vehicle Color         | RD
#  Feet From Curb        | 0
#  Violation Description | 78-Nighttime PKG ...
# -RECORD 1-------------------------------------
#  Summons Number        | 7997176457
#  Plate ID              | GFG6023
#  Registration State    | NY
#  Plate Type            | PAS
#  Issue Date            | 2013-08-09
#  Violation Code        | 51
#  Vehicle Body Type     | SUBN
#  Vehicle Make          | HONDA
#  Issuing Agency        | T
#  Violation Precinct    | 43
#  Violation Time        | null
#  Violation County      | BX
#  Street Name           | Wheeler Ave
#  Law Section           | 408
#  Sub Division          | e3
#  Vehicle Color         | BLACK
#  Feet From Curb        | 0
#  Violation Description | 51-Sidewalk
# -RECORD 2-------------------------------------
#  Summons Number        | 7997531610
#  Plate ID              | 727LBF
#  Registration State    | CT
#  Plate Type            | PAS
#  Issue Date            | 2013-08-23
#  Violation Code        | 21
#  Vehicle Body Type     | 2DSD
#  Vehicle Make          | PORSC
#  Issuing Agency        | T
#  Violation Precinct    | 7
#  Violation Time        | null
#  Violation County      | NY
#  Street Name           | Orchard St
#  Law Section           | 408
#  Sub Division          | d1
#  Vehicle Color         | WHITE
#  Feet From Curb        | 0
#  Violation Description | 21-No Parking (st...
# -RECORD 3-------------------------------------
#  Summons Number        | 7660894250
#  Plate ID              | GDM6817
#  Registration State    | NY
#  Plate Type            | PAS
#  Issue Date            | 2013-08-17
#  Violation Code        | 21
#  Vehicle Body Type     | SUBN
#  Vehicle Make          | JEEP
#  Issuing Agency        | T
#  Violation Precinct    | 7
#  Violation Time        | null
#  Violation County      | NY
#  Street Name           | Orchard St
#  Law Section           | 408
#  Sub Division          | d1
#  Vehicle Color         | WH
#  Feet From Curb        | 0
#  Violation Description | 21-No Parking (st...
# -RECORD 4-------------------------------------
#  Summons Number        | 7663689458
#  Plate ID              | GBV1681
#  Registration State    | NY
#  Plate Type            | PAS
#  Issue Date            | 2013-08-02
#  Violation Code        | 21
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | HYUND
#  Issuing Agency        | T
#  Violation Precinct    | 7
#  Violation Time        | null
#  Violation County      | NY
#  Street Name           | Orchard St
#  Law Section           | 408
#  Sub Division          | d1
#  Vehicle Color         | BK
#  Feet From Curb        | 0
#  Violation Description | 21-No Parking (st...
# -RECORD 5-------------------------------------
#  Summons Number        | 7094409722
#  Plate ID              | HDL7988
#  Registration State    | PA
#  Plate Type            | PAS
#  Issue Date            | 2013-08-21
#  Violation Code        | 21
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | ME/BE
#  Issuing Agency        | T
#  Violation Precinct    | 84
#  Violation Time        | null
#  Violation County      | K
#  Street Name           | Willoughby St
#  Law Section           | 408
#  Sub Division          | d1
#  Vehicle Color         | WHITE
#  Feet From Curb        | 0
#  Violation Description | 21-No Parking (st...
# -RECORD 6-------------------------------------
#  Summons Number        | 7776143704
#  Plate ID              | KITTYBB
#  Registration State    | NY
#  Plate Type            | SRF
#  Issue Date            | 2013-08-24
#  Violation Code        | 17
#  Vehicle Body Type     | 2DSD
#  Vehicle Make          | MINI
#  Issuing Agency        | T
#  Violation Precinct    | 13
#  Violation Time        | null
#  Violation County      | NY
#  Street Name           | Broadway
#  Law Section           | 408
#  Sub Division          | c4
#  Vehicle Color         | RD
#  Feet From Curb        | 0
#  Violation Description | 17-No Stand (exc ...
# -RECORD 7-------------------------------------
#  Summons Number        | 7512328503
#  Plate ID              | 95806MA
#  Registration State    | NY
#  Plate Type            | COM
#  Issue Date            | 2013-07-30
#  Violation Code        | 21
#  Vehicle Body Type     | DUMP
#  Vehicle Make          | ISUZU
#  Issuing Agency        | T
#  Violation Precinct    | 70
#  Violation Time        | null
#  Violation County      | K
#  Street Name           | Coney Island Ave
#  Law Section           | 408
#  Sub Division          | d1
#  Vehicle Color         | WH
#  Feet From Curb        | 0
#  Violation Description | 21-No Parking (st...
# -RECORD 8-------------------------------------
#  Summons Number        | 7032646177
#  Plate ID              | XASP83
#  Registration State    | NJ
#  Plate Type            | PAS
#  Issue Date            | 2013-08-08
#  Violation Code        | 85
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | CHEVR
#  Issuing Agency        | T
#  Violation Precinct    | 52
#  Violation Time        | 1970-01-01 01:00:00
#  Violation County      | BX
#  Street Name           | W Kingsbridge Rd
#  Law Section           | 408
#  Sub Division          | k5
#  Vehicle Color         | WHITE
#  Feet From Curb        | 0
#  Violation Description | 85-Storage-3 hour...
# -RECORD 9-------------------------------------
#  Summons Number        | 7453597730
#  Plate ID              | LE90NB
#  Registration State    | NJ
#  Plate Type            | PAS
#  Issue Date            | 2013-08-22
#  Violation Code        | 21
#  Vehicle Body Type     | SUBN
#  Vehicle Make          | MITSU
#  Issuing Agency        | T
#  Violation Precinct    | 70
#  Violation Time        | 1970-01-01 01:00:00
#  Violation County      | K
#  Street Name           | Coney Island Ave
#  Law Section           | 408
#  Sub Division          | d1
#  Vehicle Color         | BLUE
#  Feet From Curb        | 0
#  Violation Description | 21-No Parking (st...
# only showing top 10 rows

# %%
# Check for missing values
missing_values = {col_name: df_cleaned.filter(col(col_name).isNull()).count() for col_name in df_cleaned.columns}
print("Missing values for each column:")
for col_name, missing_count in missing_values.items():
    print(f"{col_name}: {missing_count}")
# Out:
# Missing values for each column:
# Summons Number: 0
# Plate ID: 0
# Registration State: 0
# Plate Type: 0
# Issue Date: 0
# Violation Code: 0
# Vehicle Body Type: 0
# Vehicle Make: 0
# Issuing Agency: 0
# Violation Precinct: 0
# Violation Time: 157248
# Violation County: 0
# Street Name: 0
# Law Section: 0
# Sub Division: 0
# Vehicle Color: 0
# Feet From Curb: 0
# Violation Description: 0

# %%
df_cleaned = df_cleaned.dropna()
df_cleaned.count()
# Out:
# 22850787

# %%
from pyspark.sql.functions import date_format

# Assuming df is your DataFrame and 'timestamp_col' is your timestamp column
df_cleaned = df_cleaned.withColumn('Time', date_format('Violation Time', 'HH:mm:ss'))
df_cleaned.show(vertical=True)
# Out:
# -RECORD 0-------------------------------------
#  Summons Number        | 7032646177
#  Plate ID              | XASP83
#  Registration State    | NJ
#  Plate Type            | PAS
#  Issue Date            | 2013-08-08
#  Violation Code        | 85
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | CHEVR
#  Issuing Agency        | T
#  Violation Precinct    | 52
#  Violation Time        | 1970-01-01 01:00:00
#  Violation County      | BX
#  Street Name           | W Kingsbridge Rd
#  Law Section           | 408
#  Sub Division          | k5
#  Vehicle Color         | WHITE
#  Feet From Curb        | 0
#  Violation Description | 85-Storage-3 hour...
#  Time                  | 01:00:00
# -RECORD 1-------------------------------------
#  Summons Number        | 7453597730
#  Plate ID              | LE90NB
#  Registration State    | NJ
#  Plate Type            | PAS
#  Issue Date            | 2013-08-22
#  Violation Code        | 21
#  Vehicle Body Type     | SUBN
#  Vehicle Make          | MITSU
#  Issuing Agency        | T
#  Violation Precinct    | 70
#  Violation Time        | 1970-01-01 01:00:00
#  Violation County      | K
#  Street Name           | Coney Island Ave
#  Law Section           | 408
#  Sub Division          | d1
#  Vehicle Color         | BLUE
#  Feet From Curb        | 0
#  Violation Description | 21-No Parking (st...
#  Time                  | 01:00:00
# -RECORD 2-------------------------------------
#  Summons Number        | 7686632465
#  Plate ID              | GJC9376
#  Registration State    | NY
#  Plate Type            | PAS
#  Issue Date            | 2013-08-27
#  Violation Code        | 38
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | HONDA
#  Issuing Agency        | T
#  Violation Precinct    | 49
#  Violation Time        | 1970-01-01 13:00:00
#  Violation County      | BX
#  Street Name           | Boston Rd
#  Law Section           | 408
#  Sub Division          | h1
#  Vehicle Color         | BLUE
#  Feet From Curb        | 0
#  Violation Description | 38-Failure to Dis...
#  Time                  | 13:00:00
# -RECORD 3-------------------------------------
#  Summons Number        | 7799937180
#  Plate ID              | T522734C
#  Registration State    | NY
#  Plate Type            | OMT
#  Issue Date            | 2013-08-07
#  Violation Code        | 38
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | LINCO
#  Issuing Agency        | T
#  Violation Precinct    | 43
#  Violation Time        | 1970-01-01 13:00:00
#  Violation County      | BX
#  Street Name           | Starling Ave
#  Law Section           | 408
#  Sub Division          | h1
#  Vehicle Color         | GR
#  Feet From Curb        | 0
#  Violation Description | 38-Failure to Dis...
#  Time                  | 13:00:00
# -RECORD 4-------------------------------------
#  Summons Number        | 7075367626
#  Plate ID              | EAE6444
#  Registration State    | NY
#  Plate Type            | PAS
#  Issue Date            | 2013-08-20
#  Violation Code        | 14
#  Vehicle Body Type     | SUBN
#  Vehicle Make          | SATUR
#  Issuing Agency        | T
#  Violation Precinct    | 68
#  Violation Time        | 1970-01-01 13:00:00
#  Violation County      | K
#  Street Name           | 8th Ave
#  Law Section           | 408
#  Sub Division          | c
#  Vehicle Color         | GOLD
#  Feet From Curb        | 0
#  Violation Description | 14-No Standing
#  Time                  | 13:00:00
# -RECORD 5-------------------------------------
#  Summons Number        | 7741116915
#  Plate ID              | 49781MA
#  Registration State    | NY
#  Plate Type            | COM
#  Issue Date            | 2013-08-05
#  Violation Code        | 10
#  Vehicle Body Type     | DELV
#  Vehicle Make          | NS/OT
#  Issuing Agency        | T
#  Violation Precinct    | 6
#  Violation Time        | 1970-01-01 13:00:00
#  Violation County      | NY
#  Street Name           | Carmine St
#  Law Section           | 408
#  Sub Division          | b
#  Vehicle Color         | RED
#  Feet From Curb        | 0
#  Violation Description | 10-No Stopping
#  Time                  | 13:00:00
# -RECORD 6-------------------------------------
#  Summons Number        | 7553508093
#  Plate ID              | HRW3440
#  Registration State    | PA
#  Plate Type            | PAS
#  Issue Date            | 2013-08-12
#  Violation Code        | 14
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | FORD
#  Issuing Agency        | T
#  Violation Precinct    | 84
#  Violation Time        | 1970-01-01 13:01:00
#  Violation County      | K
#  Street Name           | Livingston St
#  Law Section           | 408
#  Sub Division          | c
#  Vehicle Color         | BLACK
#  Feet From Curb        | 0
#  Violation Description | 14-No Standing
#  Time                  | 13:01:00
# -RECORD 7-------------------------------------
#  Summons Number        | 7335569229
#  Plate ID              | 437XNB
#  Registration State    | AZ
#  Plate Type            | PAS
#  Issue Date            | 2013-08-14
#  Violation Code        | 10
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | TOYOT
#  Issuing Agency        | T
#  Violation Precinct    | 19
#  Violation Time        | 1970-01-01 13:01:00
#  Violation County      | NY
#  Street Name           | 1st Ave
#  Law Section           | 408
#  Sub Division          | b
#  Vehicle Color         | SILVE
#  Feet From Curb        | 0
#  Violation Description | 10-No Stopping
#  Time                  | 13:01:00
# -RECORD 8-------------------------------------
#  Summons Number        | 7937505308
#  Plate ID              | 90859JX
#  Registration State    | NY
#  Plate Type            | COM
#  Issue Date            | 2013-08-03
#  Violation Code        | 38
#  Vehicle Body Type     | REFG
#  Vehicle Make          | TOYOT
#  Issuing Agency        | T
#  Violation Precinct    | 9
#  Violation Time        | 1970-01-01 13:01:00
#  Violation County      | NY
#  Street Name           | 1st Ave
#  Law Section           | 408
#  Sub Division          | h1
#  Vehicle Color         | WH
#  Feet From Curb        | 0
#  Violation Description | 38-Failure to Dis...
#  Time                  | 13:01:00
# -RECORD 9-------------------------------------
#  Summons Number        | 7188734239
#  Plate ID              | GEX2678
#  Registration State    | NY
#  Plate Type            | PAS
#  Issue Date            | 2013-08-27
#  Violation Code        | 46
#  Vehicle Body Type     | SUBN
#  Vehicle Make          | HONDA
#  Issuing Agency        | T
#  Violation Precinct    | 44
#  Violation Time        | 1970-01-01 13:02:00
#  Violation County      | BX
#  Street Name           | Woodycrest Ave
#  Law Section           | 408
#  Sub Division          | f1
#  Vehicle Color         | BL
#  Feet From Curb        | 0
#  Violation Description | 46A-Double Parkin...
#  Time                  | 13:02:00
# -RECORD 10------------------------------------
#  Summons Number        | 7084117234
#  Plate ID              | FZW2481
#  Registration State    | NY
#  Plate Type            | PAS
#  Issue Date            | 2013-08-05
#  Violation Code        | 71
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | NISSA
#  Issuing Agency        | T
#  Violation Precinct    | 68
#  Violation Time        | 1970-01-01 13:02:00
#  Violation County      | K
#  Street Name           | 86th St
#  Law Section           | 408
#  Sub Division          | j6
#  Vehicle Color         | DKG
#  Feet From Curb        | 0
#  Violation Description | 71A-Insp Sticker ...
#  Time                  | 13:02:00
# -RECORD 11------------------------------------
#  Summons Number        | 7398976914
#  Plate ID              | 49975JG
#  Registration State    | NY
#  Plate Type            | COM
#  Issue Date            | 2013-07-31
#  Violation Code        | 69
#  Vehicle Body Type     | VAN
#  Vehicle Make          | INTER
#  Issuing Agency        | T
#  Violation Precinct    | 5
#  Violation Time        | 1970-01-01 13:02:00
#  Violation County      | NY
#  Street Name           | Broadway
#  Law Section           | 408
#  Sub Division          | h1
#  Vehicle Color         | BROWN
#  Feet From Curb        | 0
#  Violation Description | 69-Failure to Dis...
#  Time                  | 13:02:00
# -RECORD 12------------------------------------
#  Summons Number        | 7099121959
#  Plate ID              | 82730JD
#  Registration State    | NY
#  Plate Type            | COM
#  Issue Date            | 2013-08-19
#  Violation Code        | 14
#  Vehicle Body Type     | UTIL
#  Vehicle Make          | FRUEH
#  Issuing Agency        | T
#  Violation Precinct    | 109
#  Violation Time        | 1970-01-01 13:02:00
#  Violation County      | Q
#  Street Name           | Main St
#  Law Section           | 408
#  Sub Division          | c
#  Vehicle Color         | NOC
#  Feet From Curb        | 0
#  Violation Description | 14-No Standing
#  Time                  | 13:02:00
# -RECORD 13------------------------------------
#  Summons Number        | 7294366123
#  Plate ID              | GHA2088
#  Registration State    | NY
#  Plate Type            | PAS
#  Issue Date            | 2013-08-07
#  Violation Code        | 40
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | ACURA
#  Issuing Agency        | T
#  Violation Precinct    | 19
#  Violation Time        | 1970-01-01 13:03:00
#  Violation County      | NY
#  Street Name           | E 84th St
#  Law Section           | 408
#  Sub Division          | e2
#  Vehicle Color         | GY
#  Feet From Curb        | 7
#  Violation Description | 40-Fire Hydrant
#  Time                  | 13:03:00
# -RECORD 14------------------------------------
#  Summons Number        | 7721081397
#  Plate ID              | 48980MC
#  Registration State    | NY
#  Plate Type            | COM
#  Issue Date            | 2013-08-19
#  Violation Code        | 20
#  Vehicle Body Type     | VAN
#  Vehicle Make          | CHEVR
#  Issuing Agency        | T
#  Violation Precinct    | 5
#  Violation Time        | 1970-01-01 13:04:00
#  Violation County      | NY
#  Street Name           | E Houston St
#  Law Section           | 408
#  Sub Division          | d
#  Vehicle Color         | WH
#  Feet From Curb        | 0
#  Violation Description | 20-No Parking (Co...
#  Time                  | 13:04:00
# -RECORD 15------------------------------------
#  Summons Number        | 7661742688
#  Plate ID              | 82379JW
#  Registration State    | NY
#  Plate Type            | COM
#  Issue Date            | 2013-08-07
#  Violation Code        | 42
#  Vehicle Body Type     | VAN
#  Vehicle Make          | FORD
#  Issuing Agency        | T
#  Violation Precinct    | 17
#  Violation Time        | 1970-01-01 13:04:00
#  Violation County      | NY
#  Street Name           | 3rd Ave
#  Law Section           | 408
#  Sub Division          | h1
#  Vehicle Color         | WH
#  Feet From Curb        | 0
#  Violation Description | 42-Exp. Muni-Mtr ...
#  Time                  | 13:04:00
# -RECORD 16------------------------------------
#  Summons Number        | 7440709871
#  Plate ID              | 45374MD
#  Registration State    | NY
#  Plate Type            | COM
#  Issue Date            | 2013-08-20
#  Violation Code        | 85
#  Vehicle Body Type     | UTIL
#  Vehicle Make          | FHTL
#  Issuing Agency        | T
#  Violation Precinct    | 108
#  Violation Time        | 1970-01-01 01:05:00
#  Violation County      | Q
#  Street Name           | 44th Dr
#  Law Section           | 408
#  Sub Division          | k5
#  Vehicle Color         | WH
#  Feet From Curb        | 0
#  Violation Description | 85-Storage-3 hour...
#  Time                  | 01:05:00
# -RECORD 17------------------------------------
#  Summons Number        | 7405841752
#  Plate ID              | GHU9908
#  Registration State    | NY
#  Plate Type            | PAS
#  Issue Date            | 2013-08-12
#  Violation Code        | 46
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | HONDA
#  Issuing Agency        | T
#  Violation Precinct    | 52
#  Violation Time        | 1970-01-01 13:05:00
#  Violation County      | BX
#  Street Name           | Perry Ave
#  Law Section           | 408
#  Sub Division          | f1
#  Vehicle Color         | SILVE
#  Feet From Curb        | 0
#  Violation Description | 46A-Double Parkin...
#  Time                  | 13:05:00
# -RECORD 18------------------------------------
#  Summons Number        | 7146561999
#  Plate ID              | FWM3579
#  Registration State    | NY
#  Plate Type            | PAS
#  Issue Date            | 2013-08-01
#  Violation Code        | 20
#  Vehicle Body Type     | SUBN
#  Vehicle Make          | LINCO
#  Issuing Agency        | T
#  Violation Precinct    | 104
#  Violation Time        | 1970-01-01 13:05:00
#  Violation County      | Q
#  Street Name           | Myrtle Ave
#  Law Section           | 408
#  Sub Division          | d
#  Vehicle Color         | TN
#  Feet From Curb        | 0
#  Violation Description | 20A-No Parking (N...
#  Time                  | 13:05:00
# -RECORD 19------------------------------------
#  Summons Number        | 7517420902
#  Plate ID              | 69FS30
#  Registration State    | MA
#  Plate Type            | PAS
#  Issue Date            | 2013-07-30
#  Violation Code        | 46
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | TOYOT
#  Issuing Agency        | T
#  Violation Precinct    | 77
#  Violation Time        | 1970-01-01 13:06:00
#  Violation County      | K
#  Street Name           | Lincoln Pl
#  Law Section           | 408
#  Sub Division          | f1
#  Vehicle Color         | TAN
#  Feet From Curb        | 0
#  Violation Description | 46A-Double Parkin...
#  Time                  | 13:06:00
# only showing top 20 rows

# %%
df_cleaned.dtypes
# Out:
# [('Summons Number', 'bigint'),
#  ('Plate ID', 'string'),
#  ('Registration State', 'string'),
#  ('Plate Type', 'string'),
#  ('Issue Date', 'date'),
#  ('Violation Code', 'int'),
#  ('Vehicle Body Type', 'string'),
#  ('Vehicle Make', 'string'),
#  ('Issuing Agency', 'string'),
#  ('Violation Precinct', 'int'),
#  ('Violation Time', 'timestamp'),
#  ('Violation County', 'string'),
#  ('Street Name', 'string'),
#  ('Law Section', 'string'),
#  ('Sub Division', 'string'),
#  ('Vehicle Color', 'string'),
#  ('Feet From Curb', 'string'),
#  ('Violation Description', 'string'),
#  ('Time', 'string')]

# %%
df_cleaned = df_cleaned.drop('Violation Time')

# %%
df_cleaned = df_cleaned.withColumnRenamed('Time', 'Violation Time')

# %%
df_cleaned.show(10,vertical=True)
# Out:
# -RECORD 0-------------------------------------
#  Summons Number        | 7032646177
#  Plate ID              | XASP83
#  Registration State    | NJ
#  Plate Type            | PAS
#  Issue Date            | 2013-08-08
#  Violation Code        | 85
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | CHEVR
#  Issuing Agency        | T
#  Violation Precinct    | 52
#  Violation County      | BX
#  Street Name           | W Kingsbridge Rd
#  Law Section           | 408
#  Sub Division          | k5
#  Vehicle Color         | WHITE
#  Feet From Curb        | 0
#  Violation Description | 85-Storage-3 hour...
#  Violation Time        | 01:00:00
# -RECORD 1-------------------------------------
#  Summons Number        | 7453597730
#  Plate ID              | LE90NB
#  Registration State    | NJ
#  Plate Type            | PAS
#  Issue Date            | 2013-08-22
#  Violation Code        | 21
#  Vehicle Body Type     | SUBN
#  Vehicle Make          | MITSU
#  Issuing Agency        | T
#  Violation Precinct    | 70
#  Violation County      | K
#  Street Name           | Coney Island Ave
#  Law Section           | 408
#  Sub Division          | d1
#  Vehicle Color         | BLUE
#  Feet From Curb        | 0
#  Violation Description | 21-No Parking (st...
#  Violation Time        | 01:00:00
# -RECORD 2-------------------------------------
#  Summons Number        | 7686632465
#  Plate ID              | GJC9376
#  Registration State    | NY
#  Plate Type            | PAS
#  Issue Date            | 2013-08-27
#  Violation Code        | 38
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | HONDA
#  Issuing Agency        | T
#  Violation Precinct    | 49
#  Violation County      | BX
#  Street Name           | Boston Rd
#  Law Section           | 408
#  Sub Division          | h1
#  Vehicle Color         | BLUE
#  Feet From Curb        | 0
#  Violation Description | 38-Failure to Dis...
#  Violation Time        | 13:00:00
# -RECORD 3-------------------------------------
#  Summons Number        | 7799937180
#  Plate ID              | T522734C
#  Registration State    | NY
#  Plate Type            | OMT
#  Issue Date            | 2013-08-07
#  Violation Code        | 38
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | LINCO
#  Issuing Agency        | T
#  Violation Precinct    | 43
#  Violation County      | BX
#  Street Name           | Starling Ave
#  Law Section           | 408
#  Sub Division          | h1
#  Vehicle Color         | GR
#  Feet From Curb        | 0
#  Violation Description | 38-Failure to Dis...
#  Violation Time        | 13:00:00
# -RECORD 4-------------------------------------
#  Summons Number        | 7075367626
#  Plate ID              | EAE6444
#  Registration State    | NY
#  Plate Type            | PAS
#  Issue Date            | 2013-08-20
#  Violation Code        | 14
#  Vehicle Body Type     | SUBN
#  Vehicle Make          | SATUR
#  Issuing Agency        | T
#  Violation Precinct    | 68
#  Violation County      | K
#  Street Name           | 8th Ave
#  Law Section           | 408
#  Sub Division          | c
#  Vehicle Color         | GOLD
#  Feet From Curb        | 0
#  Violation Description | 14-No Standing
#  Violation Time        | 13:00:00
# -RECORD 5-------------------------------------
#  Summons Number        | 7741116915
#  Plate ID              | 49781MA
#  Registration State    | NY
#  Plate Type            | COM
#  Issue Date            | 2013-08-05
#  Violation Code        | 10
#  Vehicle Body Type     | DELV
#  Vehicle Make          | NS/OT
#  Issuing Agency        | T
#  Violation Precinct    | 6
#  Violation County      | NY
#  Street Name           | Carmine St
#  Law Section           | 408
#  Sub Division          | b
#  Vehicle Color         | RED
#  Feet From Curb        | 0
#  Violation Description | 10-No Stopping
#  Violation Time        | 13:00:00
# -RECORD 6-------------------------------------
#  Summons Number        | 7553508093
#  Plate ID              | HRW3440
#  Registration State    | PA
#  Plate Type            | PAS
#  Issue Date            | 2013-08-12
#  Violation Code        | 14
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | FORD
#  Issuing Agency        | T
#  Violation Precinct    | 84
#  Violation County      | K
#  Street Name           | Livingston St
#  Law Section           | 408
#  Sub Division          | c
#  Vehicle Color         | BLACK
#  Feet From Curb        | 0
#  Violation Description | 14-No Standing
#  Violation Time        | 13:01:00
# -RECORD 7-------------------------------------
#  Summons Number        | 7335569229
#  Plate ID              | 437XNB
#  Registration State    | AZ
#  Plate Type            | PAS
#  Issue Date            | 2013-08-14
#  Violation Code        | 10
#  Vehicle Body Type     | 4DSD
#  Vehicle Make          | TOYOT
#  Issuing Agency        | T
#  Violation Precinct    | 19
#  Violation County      | NY
#  Street Name           | 1st Ave
#  Law Section           | 408
#  Sub Division          | b
#  Vehicle Color         | SILVE
#  Feet From Curb        | 0
#  Violation Description | 10-No Stopping
#  Violation Time        | 13:01:00
# -RECORD 8-------------------------------------
#  Summons Number        | 7937505308
#  Plate ID              | 90859JX
#  Registration State    | NY
#  Plate Type            | COM
#  Issue Date            | 2013-08-03
#  Violation Code        | 38
#  Vehicle Body Type     | REFG
#  Vehicle Make          | TOYOT
#  Issuing Agency        | T
#  Violation Precinct    | 9
#  Violation County      | NY
#  Street Name           | 1st Ave
#  Law Section           | 408
#  Sub Division          | h1
#  Vehicle Color         | WH
#  Feet From Curb        | 0
#  Violation Description | 38-Failure to Dis...
#  Violation Time        | 13:01:00
# -RECORD 9-------------------------------------
#  Summons Number        | 7188734239
#  Plate ID              | GEX2678
#  Registration State    | NY
#  Plate Type            | PAS
#  Issue Date            | 2013-08-27
#  Violation Code        | 46
#  Vehicle Body Type     | SUBN
#  Vehicle Make          | HONDA
#  Issuing Agency        | T
#  Violation Precinct    | 44
#  Violation County      | BX
#  Street Name           | Woodycrest Ave
#  Law Section           | 408
#  Sub Division          | f1
#  Vehicle Color         | BL
#  Feet From Curb        | 0
#  Violation Description | 46A-Double Parkin...
#  Violation Time        | 13:02:00
# only showing top 10 rows

# %%
df_cleaned.dtypes
# Out:
# [('Summons Number', 'bigint'),
#  ('Plate ID', 'string'),
#  ('Registration State', 'string'),
#  ('Plate Type', 'string'),
#  ('Issue Date', 'date'),
#  ('Violation Code', 'int'),
#  ('Vehicle Body Type', 'string'),
#  ('Vehicle Make', 'string'),
#  ('Issuing Agency', 'string'),
#  ('Violation Precinct', 'int'),
#  ('Violation County', 'string'),
#  ('Street Name', 'string'),
#  ('Law Section', 'string'),
#  ('Sub Division', 'string'),
#  ('Vehicle Color', 'string'),
#  ('Feet From Curb', 'string'),
#  ('Violation Description', 'string'),
#  ('Violation Time', 'string')]

# %%
df_cleaned.coalesce(1).write.format("csv") \
  .option("header", "true") \
  .mode("overwrite") \
  .save("output_final1_NYC.csv")

# %%
num_rows = df_cleaned.count()
num_columns = len(df_cleaned.columns)
print(f"Shape of DataFrame: ({num_rows}, {num_columns})")
